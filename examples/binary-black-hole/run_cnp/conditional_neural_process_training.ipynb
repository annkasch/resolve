# %% [markdown]
# # Conditional Neural Processes (CNP).
# [Conditional Neural Processes](https://arxiv.org/pdf/1807.01613.pdf) (CNPs) were
# introduced as a continuation of
# [Generative Query Networks](https://deepmind.com/blog/neural-scene-representation-and-rendering/)
# (GQN) to extend its training regime to tasks beyond scene rendering, e.g. to
# regression and classification.

# %%
import torch
import torch.optim as optim
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from resolve.utilities import utilities as utils
from resolve.conditional_neural_process import DataGeneration
from resolve.conditional_neural_process import DeterministicModel
from resolve.conditional_neural_process import Trainer
from torch.utils.tensorboard import SummaryWriter
import yaml

# %%
# Set the path to the yaml settings file here
path_to_settings = "../"
with open(f"{path_to_settings}/settings.yaml", "r") as f:
    config_file = yaml.safe_load(f)

torch.manual_seed(0)
BATCH_SIZE = config_file["cnp_settings"]["batch_size_train"]
LEARNING_RATE = config_file["cnp_settings"]["learning_rate"]
FILES_PER_BATCH = config_file["cnp_settings"]["files_per_batch_train"]
target_range = config_file["simulation_settings"]["target_range"]
is_binary = target_range[0] >= 0 and target_range[1] <= 1
version = config_file["path_settings"]["version"]
path_out = f'{config_file["path_settings"]["path_out_cnp"]}/{version}'

# %%
x_size, y_size = utils.get_feature_and_label_size(config_file)

# %%
d_x, d_in, representation_size, d_out = x_size , x_size+y_size, config_file["cnp_settings"]["representation_size"], y_size*2
encoder_sizes = [d_in] + config_file["cnp_settings"]["encoder_hidden_layers"] + [representation_size]
decoder_sizes = [representation_size + d_x]+ config_file["cnp_settings"]["decoder_hidden_layers"] + [d_out] 

model = DeterministicModel(encoder_sizes, decoder_sizes)

# %%
# load data:
dataset_train_1 = DataGeneration(mode = "training_phase1", 
                                config_file=config_file, 
                                path_to_files=config_file["path_settings"]["path_to_files_train"],
                                batch_size=BATCH_SIZE,
                                files_per_batch=FILES_PER_BATCH
                                )
dataset_train_1.set_loader()

# Save back to the file
with open(f"{path_to_settings}/settings.yaml", "w") as f:
    yaml.safe_dump(config_file, f, sort_keys=False)

dataset_val = DataGeneration(mode = "validation", 
                                config_file=config_file, 
                                path_to_files=config_file["path_settings"]["path_to_files_train"],
                                batch_size=BATCH_SIZE,
                                files_per_batch=FILES_PER_BATCH)

# set the feature mean and std from the training set
if config_file["feature_settings"]["use_normalization"] != False:
    dataset_val.feature_mean = dataset_train_1.feature_mean
    dataset_val.feature_std = dataset_train_1.feature_std

dataset_val.set_loader()
# Out:
# Data Processing in Progress: 100%|██████████| 1000/1000 [00:01<00:00, 564.43it/s]
# Computing global feature stats: 100%|██████████| 1000/1000 [00:06<00:00, 151.15it/s]
# Z-score feature mean/std computation completed.

# %%
os.system(f'mkdir -p {path_out}/cnp_{version}_tensorboard_logs_phase1')
os.system(f'rm {path_out}/cnp_{version}_tensorboard_logs_phase1/events*')
writer = SummaryWriter(log_dir=f'{path_out}/cnp_{version}_tensorboard_logs_phase1')

optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

# Instantiate the training wrapper for the first phase
trainer_1 = Trainer(model, dataset_train_1)
trainer_1.training_epochs = int(config_file["cnp_settings"]["training_epochs"]*config_file["cnp_settings"]["mixup_ratio"])
trainer_1.weight_fp=1.
trainer_1.weight_tp=0.1
# Train the model
trainer_1.fit(optimizer=optimizer, writer=writer, dataset_val=dataset_val)
# Out:
# Training Epoch 1/15:   3%|▎         | 52/1500 [00:16<07:32,  3.20it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 13
#      11 trainer_1.weight_tp=0.1
#      12 # Train the model
# ---> 13 trainer_1.fit(optimizer=optimizer, writer=writer, dataset_val=dataset_val)
#
# File ~/Documents/Analysis/bbh/resolve/resolve/conditional_neural_process/training_wrapper.py:185, in Trainer.fit(self, optimizer, writer, dataset_val)
#     183 total_bce_loss = 0.0
#     184 total_samples = 0
# --> 185 for b, batch in tqdm(enumerate(dataloader), total=math.ceil(len(dataloader) / self.dataset._batch_size), desc=f"Training Epoch {it_epoch+1}/{self.training_epochs}"):
#     186     it_step = it_epoch * math.ceil(len(dataloader) / self.dataset._batch_size) + b
#     187     batch_formatted = self.dataset.format_batch_for_cnp(batch, self.dataset.config_file["cnp_settings"]["context_is_subset"])
#
# File ~/.local/modules/miniconda/miniconda3/envs/resolve/lib/python3.10/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/.local/modules/miniconda/miniconda3/envs/resolve/lib/python3.10/site-packages/torch/utils/data/dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/.local/modules/miniconda/miniconda3/envs/resolve/lib/python3.10/site-packages/torch/utils/data/dataloader.py:1329, in _MultiProcessingDataLoaderIter._next_data(self)
#    1326     return self._process_data(data)
#    1328 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1329 idx, data = self._get_data()
#    1330 self._tasks_outstanding -= 1
#    1331 if self._dataset_kind == _DatasetKind.Iterable:
#    1332     # Check for _IterableDatasetStopIteration
#
# File ~/.local/modules/miniconda/miniconda3/envs/resolve/lib/python3.10/site-packages/torch/utils/data/dataloader.py:1295, in _MultiProcessingDataLoaderIter._get_data(self)
#    1291     # In this case, `self._data_queue` is a `queue.Queue`,. But we don't
#    1292     # need to call `.task_done()` because we don't use `.join()`.
#    1293 else:
#    1294     while True:
# -> 1295         success, data = self._try_get_data()
#    1296         if success:
#    1297             return data
#
# File ~/.local/modules/miniconda/miniconda3/envs/resolve/lib/python3.10/site-packages/torch/utils/data/dataloader.py:1133, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1120 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#    1121     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1122     # This can also be used as inner loop of fetching without timeout, with
#    (...)
#    1130     # Returns a 2-tuple:
#    1131     #   (bool: whether successfully get data, any: data if successful else None)
#    1132     try:
# -> 1133         data = self._data_queue.get(timeout=timeout)
#    1134         return (True, data)
#    1135     except Exception as e:
#    1136         # At timeout and error, we manually check whether any worker has
#    1137         # failed. Note that this is the only mechanism for Windows to detect
#    1138         # worker failures.
#
# File ~/.local/modules/miniconda/miniconda3/envs/resolve/lib/python3.10/multiprocessing/queues.py:113, in Queue.get(self, block, timeout)
#     111 if block:
#     112     timeout = deadline - time.monotonic()
# --> 113     if not self._poll(timeout):
#     114         raise Empty
#     115 elif not self._poll():
#
# File ~/.local/modules/miniconda/miniconda3/envs/resolve/lib/python3.10/multiprocessing/connection.py:257, in _ConnectionBase.poll(self, timeout)
#     255 self._check_closed()
#     256 self._check_readable()
# --> 257 return self._poll(timeout)
#
# File ~/.local/modules/miniconda/miniconda3/envs/resolve/lib/python3.10/multiprocessing/connection.py:424, in Connection._poll(self, timeout)
#     423 def _poll(self, timeout):
# --> 424     r = wait([self], timeout)
#     425     return bool(r)
#
# File ~/.local/modules/miniconda/miniconda3/envs/resolve/lib/python3.10/multiprocessing/connection.py:931, in wait(object_list, timeout)
#     928     deadline = time.monotonic() + timeout
#     930 while True:
# --> 931     ready = selector.select(timeout)
#     932     if ready:
#     933         return [key.fileobj for (key, events) in ready]
#
# File ~/.local/modules/miniconda/miniconda3/envs/resolve/lib/python3.10/selectors.py:416, in _PollLikeSelector.select(self, timeout)
#     414 ready = []
#     415 try:
# --> 416     fd_event_list = self._selector.poll(timeout)
#     417 except InterruptedError:
#     418     return ready
#
# KeyboardInterrupt:

# %%
os.system(f'mkdir -p {path_out}/cnp_{version}_tensorboard_logs_phase2')
os.system(f'rm {path_out}/cnp_{version}_tensorboard_logs_phase2/events*')
writer = SummaryWriter(log_dir=f'{path_out}/cnp_{version}_tensorboard_logs_phase2')

optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
dataset_train_2 = DataGeneration(mode = "training_phase2", 
                                config_file=config_file, 
                                path_to_files=config_file["path_settings"]["path_to_files_train"],
                                batch_size=BATCH_SIZE,
                                files_per_batch=FILES_PER_BATCH
                                )
# set the feature mean and std from the training set
if config_file["feature_settings"]["use_normalization"] != False:
    dataset_train_2.feature_mean = dataset_train_1.feature_mean
    dataset_train_2.feature_std = dataset_train_1.feature_std

dataset_train_2.set_loader()

# Instantiate the training wrapper for the second phase
trainer_2 = Trainer(model, dataset_train_2)
trainer_2.training_epochs = int(config_file["cnp_settings"]["training_epochs"]*(1.-config_file["cnp_settings"]["mixup_ratio"]))
trainer_2.weight_fp=0.1
trainer_2.weight_tp=0.05
trainer_2.fit(optimizer=optimizer, writer=writer, dataset_val=dataset_val)
# Out:
# ['../in/data/lf/v1.3/training_cnp/COMPAS_5000_0_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_100_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_101_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_102_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_103_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_104_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_105_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_106_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_107_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_108_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_109_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_10_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_110_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_111_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_112_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_113_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_114_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_115_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_116_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_117_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_118_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_119_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_11_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_120_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_121_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_122_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_123_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_124_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_125_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_126_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_127_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_128_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_129_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_12_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_130_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_131_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_132_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_133_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_134_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_135_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_136_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_137_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_138_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_139_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_13_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_140_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_141_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_142_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_143_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_144_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_145_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_146_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_147_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_148_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_149_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_14_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_150_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_151_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_152_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_153_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_154_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_155_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_156_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_157_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_158_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_159_resum.h5', '../in/data/lf/v1.3/training_cnp/COMPAS_5000_1 ...
# ['../in/data/lf/v1.3/training_cnp/COMPAS_5000_0_resum.h5']
# Training Epoch 1/5: 100%|██████████| 1500/1500 [03:05<00:00,  8.07it/s]
# Evaluation: 100%|██████████| 500/500 [01:08<00:00,  7.25it/s]
# Training Epoch 2/5: 100%|██████████| 1500/1500 [03:05<00:00,  8.10it/s]
# Evaluation: 100%|██████████| 500/500 [01:08<00:00,  7.26it/s]
# Training Epoch 3/5:  63%|██████▎   | 942/1500 [02:14<01:19,  7.01it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 16
#      14 # Instantiate the training wrapper for the second phase
#      15 trainer_2 = Trainer(model, dataset_train_1)
# ---> 16 trainer_2.fit(optimizer=optimizer, writer=writer, dataset_val=dataset_val)
#
# File ~/Documents/Analysis/bbh/resolve/resolve/conditional_neural_process/training_wrapper.py:183, in Trainer.fit(self, optimizer, writer, dataset_val)
#     181 total_bce_loss = 0.0
#     182 total_samples = 0
# --> 183 for b, batch in tqdm(enumerate(dataloader), total=math.ceil(len(dataloader) / self.dataset._batch_size), desc=f"Training Epoch {it_epoch+1}/{self.training_epochs}"):
#     184     it_step = it_epoch * math.ceil(len(dataloader) / self.dataset._batch_size) + b
#     185     batch_formatted = self.dataset.format_batch_for_cnp(batch, self.dataset.config_file["cnp_settings"]["context_is_subset"])
#
# File ~/.local/modules/miniconda/miniconda3/envs/resolve/lib/python3.10/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/.local/modules/miniconda/miniconda3/envs/resolve/lib/python3.10/site-packages/torch/utils/data/dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/.local/modules/miniconda/miniconda3/envs/resolve/lib/python3.10/site-packages/torch/utils/data/dataloader.py:1329, in _MultiProcessingDataLoaderIter._next_data(self)
#    1326     return self._process_data(data)
#    1328 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1329 idx, data = self._get_data()
#    1330 self._tasks_outstanding -= 1
#    1331 if self._dataset_kind == _DatasetKind.Iterable:
#    1332     # Check for _IterableDatasetStopIteration
#
# File ~/.local/modules/miniconda/miniconda3/envs/resolve/lib/python3.10/site-packages/torch/utils/data/dataloader.py:1295, in _MultiProcessingDataLoaderIter._get_data(self)
#    1291     # In this case, `self._data_queue` is a `queue.Queue`,. But we don't
#    1292     # need to call `.task_done()` because we don't use `.join()`.
#    1293 else:
#    1294     while True:
# -> 1295         success, data = self._try_get_data()
#    1296         if success:
#    1297             return data
#
# File ~/.local/modules/miniconda/miniconda3/envs/resolve/lib/python3.10/site-packages/torch/utils/data/dataloader.py:1133, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1120 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#    1121     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1122     # This can also be used as inner loop of fetching without timeout, with
#    (...)
#    1130     # Returns a 2-tuple:
#    1131     #   (bool: whether successfully get data, any: data if successful else None)
#    1132     try:
# -> 1133         data = self._data_queue.get(timeout=timeout)
#    1134         return (True, data)
#    1135     except Exception as e:
#    1136         # At timeout and error, we manually check whether any worker has
#    1137         # failed. Note that this is the only mechanism for Windows to detect
#    1138         # worker failures.
#
# File ~/.local/modules/miniconda/miniconda3/envs/resolve/lib/python3.10/multiprocessing/queues.py:113, in Queue.get(self, block, timeout)
#     111 if block:
#     112     timeout = deadline - time.monotonic()
# --> 113     if not self._poll(timeout):
#     114         raise Empty
#     115 elif not self._poll():
#
# File ~/.local/modules/miniconda/miniconda3/envs/resolve/lib/python3.10/multiprocessing/connection.py:257, in _ConnectionBase.poll(self, timeout)
#     255 self._check_closed()
#     256 self._check_readable()
# --> 257 return self._poll(timeout)
#
# File ~/.local/modules/miniconda/miniconda3/envs/resolve/lib/python3.10/multiprocessing/connection.py:424, in Connection._poll(self, timeout)
#     423 def _poll(self, timeout):
# --> 424     r = wait([self], timeout)
#     425     return bool(r)
#
# File ~/.local/modules/miniconda/miniconda3/envs/resolve/lib/python3.10/multiprocessing/connection.py:931, in wait(object_list, timeout)
#     928     deadline = time.monotonic() + timeout
#     930 while True:
# --> 931     ready = selector.select(timeout)
#     932     if ready:
#     933         return [key.fileobj for (key, events) in ready]
#
# File ~/.local/modules/miniconda/miniconda3/envs/resolve/lib/python3.10/selectors.py:416, in _PollLikeSelector.select(self, timeout)
#     414 ready = []
#     415 try:
# --> 416     fd_event_list = self._selector.poll(timeout)
#     417 except InterruptedError:
#     418     return ready
#
# KeyboardInterrupt:

# %%
dataset_test = DataGeneration(mode = "testing", 
                                config_file=config_file, 
                                path_to_files=config_file["path_settings"]["path_to_files_train"],
                                batch_size=BATCH_SIZE,
                                files_per_batch=FILES_PER_BATCH)

# set the feature mean and std from the training set
if config_file["feature_settings"]["use_normalization"] != False:
    dataset_test.feature_mean = dataset_train_1.feature_mean
    dataset_test.feature_std = dataset_train_1.feature_std

dataset_test.set_loader()
metric,_,_ = trainer_2.evaluate(dataset_test)
# Out:
# Evaluation: 100%|██████████| 500/500 [00:48<00:00, 10.25it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 13
#      10     dataset_test.feature_std = dataset_train.feature_std
#      12 dataset_test.set_loader()
# ---> 13 metric,_,_ = trainer.evaluate(dataset_test)
#
# ValueError: too many values to unpack (expected 3)

# %%
writer.close()
torch.save(model.state_dict(), f'{path_out}/cnp_{version}_model.pth')

# %%
columns = ['iteration','fidelity', 'nsamples'] + config_file["simulation_settings"]["theta_headers"] + ['y_cnp','y_cnp_err','y_raw']
# Define column dtypes to avoid ambiguity
dtypes = (
    [('iteration', float),
     ('fidelity', float),
     ('nsamples', float)] +
    [(name, float) for name in config_file["simulation_settings"]["theta_headers"]] +
    [('y_cnp', float), ('y_cnp_err', float), ('y_raw', float)]
)

df = pd.DataFrame(np.empty((0, len(dtypes)), dtype=dtypes))
df.columns = [name for name, _ in dtypes]  # Set column names
for f,file in enumerate(config_file["path_settings"]["path_to_files_predict"]):
    dataset_predict = DataGeneration(mode = "prediction", 
                                    config_file=config_file, 
                                    path_to_files=file,
                                    batch_size=BATCH_SIZE,
                                    files_per_batch=FILES_PER_BATCH)

    # set the feature mean and std from the training set
    if config_file["feature_settings"]["use_normalization"] != False:
        dataset_predict.feature_mean = dataset_train.feature_mean
        dataset_predict.feature_std = dataset_train.feature_std

    dataset_predict.set_loader()

    theta, counts, mu_avg_per_theta, sigma_avg_per_theta, y_avg_per_theta = trainer.aggretate_predictions(dataset_predict)

    iteration = config_file["path_settings"]["iteration"][f] * np.ones(len(theta)).reshape(-1, 1)
    fidelity = config_file["path_settings"]["fidelity"][f] * np.ones(len(theta)).reshape(-1, 1)
    counts = counts.reshape(-1, 1)
    data_combined = np.concatenate([iteration,fidelity,counts,theta, mu_avg_per_theta, sigma_avg_per_theta, y_avg_per_theta], axis=1)
    df = pd.concat([df, pd.DataFrame(data_combined, columns=columns)], ignore_index=True)

df.to_csv(f'{path_out}/cnp_{version}_output.csv', index=False)
# Out:
# Predicting: 100%|██████████| 250/250 [00:21<00:00, 11.81it/s]
# Predicting: 100%|██████████| 500/500 [00:32<00:00, 15.59it/s]

# %%
def get_marginalized(x_data, y_data, x_min, x_max, keep_axis, grid_steps=500):
        """
        Marginalizes predictions over all but one feature using random sampling when only one 
        prediction is available per sample (y_hf has shape (n_samples, 1)).
        """

        x_keep = x_data[:, keep_axis]

        # Define bins along the kept axis in the original scale.
        bin_edges = np.linspace(x_min, x_max, grid_steps + 1)
        bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2.0

        # For each bin, compute the median and 1σ percentiles (16th and 84th) from the samples in the bin.
        medians = np.empty(grid_steps)
        lower_vals = np.empty(grid_steps)
        upper_vals = np.empty(grid_steps)
        for i in range(grid_steps):
            # Use a half-open interval except for the last bin.
            if i < grid_steps - 1:
                mask = (x_keep >= bin_edges[i]) & (x_keep < bin_edges[i+1])
            else:
                mask = (x_keep >= bin_edges[i]) & (x_keep <= bin_edges[i+1])
            if np.sum(mask) > 0:
                bin_values = y_data[mask]
                medians[i] = np.median(bin_values)
                lower_vals[i] = np.percentile(bin_values, 16)
                upper_vals[i] = np.percentile(bin_values, 84)
            else:
                medians[i] = np.nan
                lower_vals[i] = np.nan
                upper_vals[i] = np.nan

        # Compute errors for plotting (errorbars represent the distance from the median to the percentiles)
        lower_error = medians - lower_vals
        upper_error = upper_vals - medians
        
        return bin_centers, medians, lower_error, upper_error

# %%
import matplotlib.lines as mlines
import pandas as pd
def get_marginialized_all(config_file, grid_steps=100):
        x_labels = config_file["simulation_settings"]["theta_headers"]
        x_labels_plot = config_file["simulation_settings"]["theta_headers_plot"]
        target_headers_plot = config_file["simulation_settings"]["target_headers_plot"]
        x_min = config_file["simulation_settings"]["theta_min"]
        x_max = config_file["simulation_settings"]["theta_max"]
        path_out  = config_file["path_settings"]["path_out_cnp"]
        version   = config_file["path_settings"]["version"]

        data=pd.read_csv(f'{path_out}/{version}/cnp_{version}_output.csv')
        y_label_sim = 'y_raw'
        y_label_cnp = 'y_cnp'
        fidelities  = np.unique(config_file["path_settings"]["fidelity"])
        x_data = []
        y_data = []
        y_sim = []
        y_data_min=1.
        y_data_max=0.
        y_sim_min=1.
        y_sim_max=0.
        for f in fidelities:
                x_data.append(data.loc[(data['fidelity']==f)][x_labels].to_numpy())
                y_data.append(data.loc[(data['fidelity']==f)][y_label_cnp].to_numpy())
                y_sim.append(data.loc[(data['fidelity']==f)][y_label_sim].to_numpy())
                y_data_min=min(y_data_min,np.min(y_data[-1]))
                y_data_max=max(y_data_max,np.max(y_data[-1]))
                y_sim_min=min(y_sim_min,np.min(y_sim[-1]))
                y_sim_max=max(y_sim_max,np.max(y_sim[-1]))

        colors=[["salmon","darkturquoise"],["darkred","teal"],["orangedred","darkslategrey"]]
        colors=[["teal","darkturquoise"],["darkred","teal"],["orangedred","darkslategrey"]]

        markers=['.','s','o''x']
        grid_steps = 100

        n_cols = len(x_labels)
        n_rows = 2

        fig, axes = plt.subplots(n_rows, n_cols, figsize=(10 * n_cols, 5 * n_rows), squeeze=False)

        for i, param in enumerate(x_labels_plot):
                for f in range(len(x_data)):
                        # Get marginalized draws
                        x_cnp, y_cnp, _, _ = get_marginalized(
                        x_data=x_data[f], y_data=y_data[f],
                        x_min=x_min[i], x_max=x_max[i], keep_axis=i, grid_steps=grid_steps
                        )

                        x_raw, y_raw, _, _ = get_marginalized(
                        x_data=x_data[f], y_data=y_sim[f],
                        x_min=x_min[i], x_max=x_max[i], keep_axis=i, grid_steps=grid_steps
                        )

                        # First row: y_cnp
                        ax_cnp = axes[1][i]
                        ax_cnp.scatter(x_cnp, y_cnp, color=colors[f][0], alpha=1., marker=markers[f], s=200)
                        if f == 0:
                                if i == 0: ax_cnp.set_ylabel(target_headers_plot+"$_{CNP}$", fontsize=24)
                                #if i== 0: ax_cnp.set_xscale('log')
                                ax_cnp.set_xlabel(param, fontsize=24)
                                #ax_cnp.tick_params(axis='y', labelcolor=colors[f][0])

                        # Second row: y_raw
                        ax_raw = axes[0][i]
                        ax_raw.scatter(x_raw, y_raw, color=colors[f][1], alpha=1., marker=markers[f], s=200)
                        if f == 0 and i == 0:
                                ax_raw.set_ylabel(target_headers_plot+"$_{raw}$", fontsize=24)
                                #if i== 0: ax_raw.set_xscale('log')
                                #ax_raw.set_xlabel(param, fontsize=16)
                                #ax_raw.tick_params(axis='y', labelcolor=colors[f][1])
                        ax_cnp.tick_params(axis='both', labelsize=14)
                        ax_raw.tick_params(axis='both', labelsize=14)

        # Construct legend
        handles = []
        handles.append(mlines.Line2D([], [], color=colors[0][0], marker=markers[0],markersize=50, linestyle='None', label=f'before CNP'))
        handles.append(mlines.Line2D([], [], color=colors[0][1], marker=markers[0],markersize=50, linestyle='None', label=f'after CNP'))

        fig.legend(
        handles=handles,
        ncol=2 * len(x_data),
        bbox_to_anchor=(0.98, 1.07),
        fontsize=24
        )

        fig.tight_layout(rect=[0, 0.05, 1, 1])  # leave space for the legend


        # Adjust layout
        plt.tight_layout()
        return fig

# %%
fig=get_marginialized_all(config_file=config_file)

fig.savefig(f'{path_out}/cnp_{version}_output.png')

# %%
trainer.metrics_train
# Out:
# {'LogProb': 0.5869849804242452,
#  'MAE': 0.0779050812125206,
#  'MSE': 0.03316458687186241,
#  'R2': 0.8034207224845886,
#  'Accuracy': 0.797620895522388,
#  'Precision': 0.19016960816062176,
#  'Recall': 0.9338004372888093,
#  'F1': 0.315987893055322,
#  'ROC_AUC': 0.8621224897481138,
#  'Average_Precision': 0.18089439360768883,
#  'BCE': 0.18792106147607168}

# %% [markdown]
# #  Start TensorBoard

# %% [markdown]
# Run this in terminal:
#
# tensorboard --logdir=\<path to tensor board log dir\> --host=0.0.0.0 --port=7007
#
# Open:
#
# http://localhost:7007/
